# %% [markdown]
# <a href="https://colab.research.google.com/github/iptracej/Llama2_colab/blob/main/SimpleChat1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 21.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 31.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 36.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 57.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 55.0 MB/s eta 0:00:00
# ...

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !huggingface-cli whoami
# Out:
# iptracej

# %%
from transformers import AutoTokenizer
model = "meta-llama/Llama-2-7b-chat-hf"
tokenizer = AutoTokenizer.from_pretrained(model, use_auth_token=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:640: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# ...

# %%
from transformers import pipeline

llama_pipeline = pipeline(
    "text-generation",
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-82121df3c4e2> in <cell line: 3>()
#       4     "text-generation",
#       5     model=model,
# ----> 6     torch_dtype=torch.float16,
#       7     device_map="auto",
#       8 )
#
# NameError: name 'torch' is not defined

# %%
# !pip install torch

# %%
import torch
from transformers import pipeline

llama_pipeline = pipeline(
    "text-generation",
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
def get_llama_response(prompt: str) -> None:
    """
    Generate a response from the Llama model.

    Parameters:
        prompt (str): The user's input/question for the model.

    Returns:
        None: Prints the model's response.
    """

    sequences = llama_pipeline(
        prompt,
        do_sample=True,
        top_k=10,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
        max_length=256,
    )
    print("Chatbot:", sequences[0]['generated_text'])

# %%
prompt = 'How to learn fast?\n'
get_llama_response(prompt)
# Out:
# Chatbot: How to learn fast?
#
# Answer: Here are some tips on how to learn fast:
#
# 1. Set clear goals: Setting specific goals helps you focus your efforts and stay motivated. Write down what you want to achieve and track your progress.
# 2. Use active learning techniques: Engage with the material you're learning by asking questions, summarizing what you've read, or explaining it to someone else. The more you interact with the material, the more likely you are to retain it.
# 3. Break it down: Break down complex topics into smaller chunks, and focus on one thing at a time. This helps you avoid feeling overwhelmed and makes it easier to understand and retain the information.
# 4. Practice consistently: Consistency is key to learning fast. Set aside a specific time each day or week to practice what you're learning, and stick to it.
# ...

# %%
while True:
    user_input = input("You: ")
    if user_input.lower() in ["bye", "quit", "exit"]:
        print("Chatbot: Goodbye!")
        break
    get_llama_response(user_input)
# Out:
# You: Hello Llama2!
# Chatbot: Hello Llama2!
#
# Hello! I'm Llama2, and I'm here to help you with any questions or problems you might have. How can I assist you today?
# You: who is the president of United States.
# Chatbot: who is the president of United States. He is the 45th president of the country and he has been in the office since 2017.
#
# What is the name of the president of the United States?
# Answer: The name of the president of the United States is Donald Trump.
# You: No. Current president of United States
# Chatbot: No. Current president of United States is Joe Biden.
# You: what is sql injection?
# Chatbot: what is sql injection?
#
# SQL injection is a type of web application security vulnerability that occurs when an attacker is able to inject malicious SQL code into a web application's database queries. This can allow the attacker to execute unauthorized actions on the database, such as stealing sensitive data or modifying data without authorization.
#
# ...
